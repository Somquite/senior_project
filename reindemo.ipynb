# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import tensorflow as tf
from tensorflow.contrib.layers import flatten
import pickle
import numpy as np
import matplotlib.pyplot as plt
import random
# %matplotlib inline
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
import cv2
import glob
import matplotlib.image as mpimg
from PIL import Image
import math
import os
import time

from utils import preprocess_data, next_batch, calculate_accuracy

from config import *

coef = 0.00005
# Out:
# WARNING:tensorflow:Deprecation warnings have been disabled. Set TF_ENABLE_DEPRECATION_WARNINGS=1 to re-enable them.
# 1.15.5
# WARNING:tensorflow:From /utils.py:32: The name tf.train.GradientDescentOptimizer is deprecated. Please use tf.compat.v1.train.GradientDescentOptimizer instead.

# %%
training_file = "./train.p"
testing_file = "./test.p"

with open(training_file, mode='rb') as f:
    train = pickle.load(f)
with open(testing_file, mode='rb') as f:
    test = pickle.load(f)
    
X_train, y_train = train['features'], train['labels']
X_test, y_test = test['features'], test['labels']

print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)
print("X_test shape:", X_test.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (39209, 32, 32, 3)
# y_train shape: (39209,)
# X_test shape: (12630, 32, 32, 3)
# y_test shape: (12630,)

# %%
#Visualization the dataset
import matplotlib.pyplot as plt
import random
# %matplotlib inline

# show image of 10 random data points
fig, axs = plt.subplots(2,5, figsize=(15, 6))
fig.subplots_adjust(hspace = .2, wspace=.001)
axs = axs.ravel()
for i in range(10):
    index = random.randint(0, len(X_train))
    image = X_train[index]
    axs[i].axis('off')
    axs[i].imshow(image)
    axs[i].set_title(y_train[index])

# %%
BATCH_SIZE = 100  # batch size for training (relatively small)
BATCH_SIZE_INF = 2048  # batch size for running inference, e.g. calculating accuracy
VALIDATION_SIZE = 0.2  # fraction of total training set to use as validation set

# %%
## Normalize the train and test datasets to (-1,1)
X_train, y_train = preprocess_data(X_train, y_train)
X_test, y_test = preprocess_data(X_test, y_test)

X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=VALIDATION_SIZE)

# %%
from tensorflow.contrib.layers import flatten

def LeNet2(x):    
    mu = 0
    sigma = 0.1
    
    # Layer 1: Convolutional. Input = 32x32x1. Output = 28x28x6.
    W1 = tf.Variable(tf.truncated_normal(shape=(5, 5, 1, 6), mean = mu, stddev = sigma), name="W1")
    x = tf.nn.conv2d(x, W1, strides=[1, 1, 1, 1], padding='VALID')
    b1 = tf.Variable(tf.zeros(6), name="b1")
    x = tf.nn.bias_add(x, b1)
    print("layer 1 shape:",x.get_shape())

    #Activation.
    x = tf.nn.relu(x)
    
    #Pooling. Input = 28x28x6. Output = 14x14x6.
    x = tf.nn.max_pool(x, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='VALID')
    layer1 = x
    
    #Layer 2: Convolutional. Output = 10x10x16.
    W2 = tf.Variable(tf.truncated_normal(shape=(5, 5, 6, 16), mean = mu, stddev = sigma), name="W2")
    x = tf.nn.conv2d(x, W2, strides=[1, 1, 1, 1], padding='VALID')
    b2 = tf.Variable(tf.zeros(16), name="b2")
    x = tf.nn.bias_add(x, b2)
                     
    #Activation.
    x = tf.nn.relu(x)

    #Pooling. Input = 10x10x16. Output = 5x5x16.
    x = tf.nn.max_pool(x, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='VALID')
    layer2 = x
    
    #Layer 3: Convolutional. Output = 1x1x400.
    W3 = tf.Variable(tf.truncated_normal(shape=(5, 5, 16, 400), mean = mu, stddev = sigma), name="W3")
    x = tf.nn.conv2d(x, W3, strides=[1, 1, 1, 1], padding='VALID')
    b3 = tf.Variable(tf.zeros(400), name="b3")
    x = tf.nn.bias_add(x, b3)
                     
    #Activation.
    x = tf.nn.relu(x)
    layer3 = x

    #Flatten. Input = 5x5x16. Output = 400.
    layer2flat = flatten(layer2)
    print("layer2flat shape:",layer2flat.get_shape())
    
    # Flatten x. Input = 1x1x400. Output = 400.
    xflat = flatten(x)
    print("xflat shape:",xflat.get_shape())
    
    # Concat layer2flat and x. Input = 400 + 400. Output = 800
    x = tf.concat([xflat, layer2flat], 1)
    print("x shape:",x.get_shape())
    
    # Dropout
    x = tf.nn.dropout(x, keep_prob)
    
    #Layer 4: Fully Connected. Input = 800. Output = 43.
    W4 = tf.Variable(tf.truncated_normal(shape=(800, 43), mean = mu, stddev = sigma), name="W4")
    b4 = tf.Variable(tf.zeros(43), name="b4")    
    logits = tf.add(tf.matmul(x, W4), b4)
    

    
    return logits

print('done')
# Out:
# done

# %%
tf.reset_default_graph() 

x = tf.placeholder(tf.float32, (None, IMG_SIZE, IMG_SIZE, 3))
y = tf.placeholder(tf.float32, (None, NUM_CLASSES))
keep_prob = tf.placeholder(tf.float32) # probability to keep units
print('done')
# Out:
# done

# %%
logits = LeNet2(x)
rate = 0.0009

correct_logit = tf.reduce_sum(y * logits, axis=1)
wrong_logit = tf.reduce_max((1-y) * logits, axis=1)
reg_loss =  correct_logit - wrong_logit
cw_grad = tf.gradients(reg_loss,x)[0]
vis = tf.gradients(correct_logit,x)[0]

cross_entropy = tf.nn.softmax_cross_entropy_with_logits(labels = y, logits = logits)
loss_operation = tf.reduce_mean(cross_entropy)

grad = tf.gradients(loss_operation,x)[0]
grad_loss = tf.nn.l2_loss(grad)
predictions = tf.argmax(logits, 1)

optimizer = tf.train.AdamOptimizer(learning_rate = rate)

training_operation = optimizer.minimize(loss_operation+50*grad_loss)

predictions = tf.argmax(logits, 1)
correct_prediction = tf.equal(predictions, tf.argmax(y, 1))
accuracy_operation = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

print("done")
# Out:
# layer 1 shape: (?, 28, 28, 6)
# layer2flat shape: (?, 400)
# xflat shape: (?, 400)
# x shape: (?, 800)
# done

# %%
global_step = tf.train.get_or_create_global_step()

grad_loss = coef * tf.reduce_sum(tf.nn.l2_loss(cw_grad))

total_loss = loss_operation + grad_loss

training_operation = optimizer.minimize(total_loss, global_step=global_step)

print("done")
# Out:
# done

# %%
saver = tf.train.Saver()


def evaluate(X_data, y_data):
    num_examples = len(X_data)
    total_accuracy = 0
    sess = tf.get_default_session()
    for offset in range(0, num_examples, BATCH_SIZE):
        batch_x, batch_y = X_data[offset:offset+BATCH_SIZE], y_data[offset:offset+BATCH_SIZE]
        accuracy = sess.run(accuracy_operation, feed_dict={x: batch_x, y: batch_y, keep_prob: 1.0})
        total_accuracy += (accuracy * len(batch_x))
    return total_accuracy / num_examples

print('done')
# Out:
# done

# %%
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    num_examples = len(X_train)
    
    print("Let's start the training...")
    print()
    for i in range(NUM_EPOCH):
        for offset in range(0, num_examples, BATCH_SIZE):
            end = offset + BATCH_SIZE
            batch_x, batch_y = X_train[offset:end], y_train[offset:end]
            sess.run(training_operation, feed_dict={x: batch_x, y: batch_y, keep_prob: 0.5})
            
        validation_accuracy = evaluate(X_valid, y_valid)
        print("EPOCH {} ...".format(i+1))
        print("Validation Accuracy = {:.3f}".format(validation_accuracy))
        print()
        
    saver.save(sess, 'rein_model')
    print("Model saved")
# Out:
# Let's start the training...
#
# EPOCH 1 ...
# Validation Accuracy = 0.053
#
# EPOCH 2 ...
# Validation Accuracy = 0.064
#
# EPOCH 3 ...
# Validation Accuracy = 0.091
#
# EPOCH 4 ...
# Validation Accuracy = 0.113
#
# EPOCH 5 ...
# Validation Accuracy = 0.233
#
# EPOCH 6 ...
# Validation Accuracy = 0.321
#
# EPOCH 7 ...
# Validation Accuracy = 0.572
#
# EPOCH 8 ...
# Validation Accuracy = 0.737
#
# EPOCH 9 ...
# Validation Accuracy = 0.814
#
# EPOCH 10 ...
# Validation Accuracy = 0.863
#
# EPOCH 11 ...
# Validation Accuracy = 0.869
#
# EPOCH 12 ...
# Validation Accuracy = 0.899
#
# EPOCH 13 ...
# Validation Accuracy = 0.917
#
# EPOCH 14 ...
# Validation Accuracy = 0.934
#
# EPOCH 15 ...
# Validation Accuracy = 0.927
#
# EPOCH 16 ...
# Validation Accuracy = 0.944
#
# EPOCH 17 ...
# Validation Accuracy = 0.951
#
# EPOCH 18 ...
# Validation Accuracy = 0.955
#
# EPOCH 19 ...
# Validation Accuracy = 0.952
#
# EPOCH 20 ...
# Validation Accuracy = 0.954
#
# EPOCH 21 ...
# Validation Accuracy = 0.961
#
# EPOCH 22 ...
# Validation Accuracy = 0.961
#
# EPOCH 23 ...
# Validation Accuracy = 0.964
#
# EPOCH 24 ...
# Validation Accuracy = 0.962
#
# EPOCH 25 ...
# Validation Accuracy = 0.966
#
# EPOCH 26 ...
# Validation Accuracy = 0.959
#
# EPOCH 27 ...
# Validation Accuracy = 0.961
#
# EPOCH 28 ...
# Validation Accuracy = 0.968
#
# EPOCH 29 ...
# Validation Accuracy = 0.967
#
# EPOCH 30 ...
# Validation Accuracy = 0.970
#
# EPOCH 31 ...
# Validation Accuracy = 0.971
#
# EPOCH 32 ...
# Validation Accuracy = 0.969
#
# EPOCH 33 ...
# Validation Accuracy = 0.971
#
# EPOCH 34 ...
# Validation Accuracy = 0.975
#
# EPOCH 35 ...
# Validation Accuracy = 0.973
#
# EPOCH 36 ...
# Validation Accuracy = 0.974
#
# EPOCH 37 ...
# Validation Accuracy = 0.972
#
# EPOCH 38 ...
# Validation Accuracy = 0.976
#
# EPOCH 39 ...
# Validation Accuracy = 0.976
#
# EPOCH 40 ...
# Validation Accuracy = 0.968
#
# EPOCH 41 ...
# Validation Accuracy = 0.975
#
# EPOCH 42 ...
# Validation Accuracy = 0.971
#
# EPOCH 43 ...
# Validation Accuracy = 0.971
#
# EPOCH 44 ...
# Validation Accuracy = 0.975
#
# EPOCH 45 ...
# Validation Accuracy = 0.969
#
# EPOCH 46 ...
# Validation Accuracy = 0.979
#
# EPOCH 47 ...
# Validation Accuracy = 0.975
#
# EPOCH 48 ...
# Validation Accuracy = 0.977
#
# EPOCH 49 ...
# Validation Accuracy = 0.971
#
# EPOCH 50 ...
# Validation Accuracy = 0.978
#
# EPOCH 51 ...
# Validation Accuracy = 0.978
#
# EPOCH 52 ...
# Validation Accuracy = 0.976
#
# EPOCH 53 ...
# Validation Accuracy = 0.972
#
# EPOCH 54 ...
# Validation Accuracy = 0.979
#
# EPOCH 55 ...
# Validation Accuracy = 0.975
#
# EPOCH 56 ...
# Validation Accuracy = 0.982
#
# EPOCH 57 ...
# Validation Accuracy = 0.980
#
# EPOCH 58 ...
# Validation Accuracy = 0.978
#
# EPOCH 59 ...
# Validation Accuracy = 0.966
#
# EPOCH 60 ...
# Validation Accuracy = 0.980
#
# Model saved

# %%
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    saver2 = tf.train.import_meta_graph('./models/rein_model.meta')
    saver2.restore(sess, "./models/rein_model")
    test_accuracy = evaluate(X_test, y_test)
    print("Test Set Accuracy = {:.3f}".format(test_accuracy))
# Out:
# INFO:tensorflow:Restoring parameters from ./rein_model
# Test Set Accuracy = 0.916

# %% [markdown]
# Rain
#
#
# $$
# X_{rain} = Mp * X_{org} + \alpha 1 - Mp * Rain,
# $$
# $X_{org}$ = original,
# $X_{rain}$ = observed image,

# %%
import copy
def rain(images, eps):
    x = copy.copy(images)
    batch_size = images.shape[0]
    for i in range(batch_size):
#         if np.mean(x[i]) > 100 and i < 1:
#             x[i] = x[i] / (1+eps*0.15)
        for j in range(eps*40):
            np.random.seed(j)
            x_idx = np.random.randint(0, 32)
            y_idx = np.random.randint(0, 32)
            x[i, x_idx:x_idx+2, y_idx, :] = 0.8*x[i, x_idx:x_idx+2, y_idx, :] + 0.2*255
    x = np.clip(x, 0., 255.)
    return x

# %%
def fog(images, eps):
    x = copy.copy(images)
    batch_size = images.shape[0]
#     x = x / (eps*0.3+1) + eps * 10
    x = x *(1-eps*0.04) + eps * 7
#     for i in range(batch_size):
#         image = x[i].reshape(32, 32, 3)
#         temp = gaussian_filter(image, sigma=0.7)
#         x[i] = temp
    x = np.clip(x, 0., 255.)
    return x

# %%
import copy
def dark(images, eps):
    x = copy.copy(images)
    x = x - eps*10.
    x = np.clip(x, 0., 255.)
    return x

def light(images, eps):
    x = copy.copy(images)
    x = x + eps*10.
    x = np.clip(x, 0., 255.)
    return x

# %%
from scipy.ndimage.filters import gaussian_filter

def blur(images, eps):
    batch_size = images.shape[0]
    x = np.zeros(images.shape)
    for i in range(batch_size):
        image = images[i].reshape(32, 32, 3)
        temp = gaussian_filter(image, sigma=0.5+eps*0.1)
        x[i] = temp
    return x

# %%
def ocul(images, eps):
    batch_size = images.shape[0]
    x = copy.copy(images)
    for i in range(batch_size):
        image = images[i].reshape(32, 32, 3)
        idx = np.random.randint(0, 32-eps)
        x[i, idx:idx+eps, idx:idx+eps, :] = 0.
#         x[i] = image
    return x

# %%
testing_file = "./test.p"

with open(testing_file, mode='rb') as f:
    test = pickle.load(f)
    
X_test, y_test = test['features'], test['labels']
print("X_test shape:", X_test.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_test shape: (12630, 32, 32, 3)
# y_test shape: (12630,)

# %%
X_test, y_test = preprocess_data(X_test, y_test)

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    saver3 = tf.train.import_meta_graph('./rein_model.meta')
    saver3.restore(sess, "./rein_model")
    acc = evaluate(X_test, y_test)
    print("Test Set Accuracy = {:.3f}".format(acc))
    for i in range(20):
        rain_images = rain(X_test, i)
        adv_acc = evaluate(rain_images, y_test)
        print("Rain Drops %.2d  vs. Accuracy vs Adv_Accuracy：" % i, acc, adv_acc)
    for i in range(20):
        rain_images = fog(X_test, i)
        adv_acc = evaluate(rain_images, y_test)
        print("fog Drops %.2d  vs. Accuracy vs Adv_Accuracy：" % i, acc, adv_acc)
    for i in range(20):
        rain_images = light(X_test, i)
        adv_acc = evaluate(rain_images, y_test)
        print("light Drops %.2d  vs. Accuracy vs Adv_Accuracy：" % i, acc, adv_acc)
    for i in range(20):
        rain_images = dark(X_test, i)
        adv_acc = evaluate(rain_images, y_test)
        print("dark Drops %.2d  vs. Accuracy vs Adv_Accuracy：" % i, acc, adv_acc)
    for i in range(20):
        rain_images = blur(X_test, i)
        adv_acc = evaluate(rain_images, y_test)
        print("Blur deviation %.2d  vs. Accuracy vs Adv_Accuracy：" % i, acc, adv_acc)
# Out:
# INFO:tensorflow:Restoring parameters from ./rein_model
# Test Set Accuracy = 0.916
# Rain Drops 00  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.9163895488634811
# Rain Drops 01  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.7661124279550022
# Rain Drops 02  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.7281868580023825
# Rain Drops 03  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.7163895502603913
# Rain Drops 04  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.6920031681479865
# Rain Drops 05  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.6308788596309562
# Rain Drops 06  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.6026128245457145
# Rain Drops 07  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.6000791747987223
# Rain Drops 08  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.6175771973384153
# Rain Drops 09  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.5874109238692908
# Rain Drops 10  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.5469516972559176
# Rain Drops 11  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.5217735526208734
# Rain Drops 12  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.5144893075158836
# Rain Drops 13  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.5297703848693075
# Rain Drops 14  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.5204275516130956
# Rain Drops 15  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.5264449707591524
# Rain Drops 16  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.5277117932494066
# Rain Drops 17  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.5113222446124513
# Rain Drops 18  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.49224069261494274
# Rain Drops 19  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.5068883578737671
# fog Drops 00  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.9163895488634811
# fog Drops 01  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.9138559002963117
# fog Drops 02  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.909580366156541
# fog Drops 03  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.9056215370258262
# fog Drops 04  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.9003167085390854
# fog Drops 05  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.8947743472841554
# fog Drops 06  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.889627868942297
# fog Drops 07  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.8824228000187817
# fog Drops 08  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.8730799676592352
# fog Drops 09  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.8596991302942532
# fog Drops 10  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.8445764029677294
# fog Drops 11  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.8240696778867515
# fog Drops 12  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.8026128266410797
# fog Drops 13  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.7775138515569063
# fog Drops 14  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.7492478226067429
# fog Drops 15  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.7174188479108652
# fog Drops 16  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.6839271589393948
# fog Drops 17  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.651068884091819
# fog Drops 18  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.6107680117999007
# fog Drops 19  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.5634996000491526
# light Drops 00  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.9163895488634811
# light Drops 01  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.9107680153676846
# light Drops 02  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.9043547136860997
# light Drops 03  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.8960411747296652
# light Drops 04  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.8874109276022499
# light Drops 05  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.8776722096396361
# light Drops 06  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.8680918460692665
# light Drops 07  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.8570071267213315
# light Drops 08  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.8424386363697731
# light Drops 09  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.8259699121884476
# light Drops 10  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.8066508314577436
# light Drops 11  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.782185271913252
# light Drops 12  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.7577988918301423
# light Drops 13  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.7272367360850506
# light Drops 14  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.6954869350458267
# light Drops 15  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.6548693583583606
# light Drops 16  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.6036421206860153
# light Drops 17  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.5466349926480016
# light Drops 18  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.4847980979313854
# light Drops 19  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.4042755336584029
# dark Drops 00  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.9163895488634811
# dark Drops 01  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.9178939054433259
# dark Drops 02  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.9019002405217217
# dark Drops 03  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.8498020559100999
# dark Drops 04  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.7845605690613306
# dark Drops 05  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.7264449722882027
# dark Drops 06  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.6771971478598134
# dark Drops 07  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.6259699113672911
# dark Drops 08  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.580997623438318
# dark Drops 09  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.5304829740892397
# dark Drops 10  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.48416468427941994
# dark Drops 11  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.44592240327705207
# dark Drops 12  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.4088677735151229
# dark Drops 13  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.3775138549642344
# dark Drops 14  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.35035629703804133
# dark Drops 15  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.3213776727564639
# dark Drops 16  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.2931116403848145
# dark Drops 17  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.2714172608542801
# dark Drops 18  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.25288994514743957
# dark Drops 19  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.23547110085391093
# Blur deviation 00  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.9070467194770879
# Blur deviation 01  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.8969121151563202
# Blur deviation 02  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.8821852746598794
# Blur deviation 03  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.8623911299501632
# Blur deviation 04  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.8391923981343388
# Blur deviation 05  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.8073634185775914
# Blur deviation 06  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.7747426713069846
# Blur deviation 07  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.7423594621373658
# Blur deviation 08  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.7087885993676627
# Blur deviation 09  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.679809977304152
# Blur deviation 10  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.6551860665765341
# Blur deviation 11  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.6335708648556296
# Blur deviation 12  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.611955660586308
# Blur deviation 13  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.5902612800647226
# Blur deviation 14  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.5680918420767463
# Blur deviation 15  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.5431512249478818
# Blur deviation 16  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.5132224817221257
# Blur deviation 17  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.4769596140345032
# Blur deviation 18  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.44687252389657905
# Blur deviation 19  vs. Accuracy vs Adv_Accuracy： 0.9163895488634811 0.4152810760697767

# %%
#reading in an image
import glob
import matplotlib.image as mpimg

fig, axs = plt.subplots(2,4, figsize=(4, 2))
fig.subplots_adjust(hspace = .2, wspace=.001)
axs = axs.ravel()

my_images = []

for i, img in enumerate(glob.glob('./traffic-signs-test/*x.png')):
    image = cv2.imread(img)
    axs[i].axis('off')
    axs[i].imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    image = np.reshape(image, (32, 32, 3))
    my_images.append(image)

my_images = np.asarray(my_images,dtype='uint8')
copy_images = my_images

# %%
label_map = {}
with open('signnames.csv', 'r') as f:
    first_line = True
    for line in f:
        # Ignore first line
        if first_line:
            first_line = False
            continue

        # Populate label_map
        label_int, label_string = line.split(',')
        label_int = int(label_int)

        label_map[label_int] = label_string

# %%
print(label_map)
# Out:
# {0: 'Speed limit (20km/h)\n', 1: 'Speed limit (30km/h)\n', 2: 'Speed limit (50km/h)\n', 3: 'Speed limit (60km/h)\n', 4: 'Speed limit (70km/h)\n', 5: 'Speed limit (80km/h)\n', 6: 'End of speed limit (80km/h)\n', 7: 'Speed limit (100km/h)\n', 8: 'Speed limit (120km/h)\n', 9: 'No passing\n', 10: 'No passing for vechiles over 3.5 metric tons\n', 11: 'Right-of-way at the next intersection\n', 12: 'Priority road\n', 13: 'Yield\n', 14: 'Stop\n', 15: 'No vechiles\n', 16: 'Vechiles over 3.5 metric tons prohibited\n', 17: 'No entry\n', 18: 'General caution\n', 19: 'Dangerous curve to the left\n', 20: 'Dangerous curve to the right\n', 21: 'Double curve\n', 22: 'Bumpy road\n', 23: 'Slippery road\n', 24: 'Road narrows on the right\n', 25: 'Road work\n', 26: 'Traffic signals\n', 27: 'Pedestrians\n', 28: 'Children crossing\n', 29: 'Bicycles crossing\n', 30: 'Beware of ice/snow\n', 31: 'Wild animals crossing\n', 32: 'End of all speed and passing limits\n', 33: 'Turn right ahead\n', 34: 'Turn left ahead\n', 35: 'Ahead only\n', 36: 'Go straight or right\n', 37: 'Go straight or left\n', 38: 'Keep right\n', 39: 'Keep left\n', 40: 'Roundabout mandatory\n', 41: 'End of no passing\n', 42: 'End of no passing by vechiles over 3.5 metric tons\n'}

# %%
my_images, _ = preprocess_data(my_images, np.array([0 for _ in range(my_images.shape[0])]))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    saver3 = tf.train.import_meta_graph('./rein_model.meta')
    saver3.restore(sess, "./rein_model")
    lgts, preds = sess.run([logits, predictions], feed_dict={x: my_images, keep_prob: 1.})
    final_preds = [label_map[pred] for pred in preds]
# Out:
# INFO:tensorflow:Restoring parameters from ./rein_model

# %%
# Print predictions on my sample images
print('Predictions on sample images\n')
for i in range(my_images.shape[0]):
    print('%s' % (final_preds[i]))
# Out:
# Predictions on sample images
#
# Turn left ahead
#
# Speed limit (70km/h)
#
# Right-of-way at the next intersection
#
# General caution
#
# Keep right
#
# Speed limit (30km/h)
#
# Speed limit (60km/h)
#
# Roundabout mandatory

# %%
with tf.Graph().as_default(), tf.Session() as sess:
    logits = tf.placeholder('float', [None, NUM_CLASSES])
    softmax = tf.nn.softmax(logits)
    top_k_val, top_k_idx = tf.nn.top_k(softmax, k=5)
    
    top_k_vals, top_k_idxs = sess.run([top_k_val, top_k_idx], feed_dict={logits: lgts})

# %%
def display_pred_certainty(copy_image, image, top_k_val, top_k_idx):
    print('Top 5 predictions for the following image (prediction: probability)')
    # Convert top k indices into strings
    top_k_pred = [label_map[idx] for idx in top_k_idx]
    
    # Show the image for reference
    fig, axs = plt.subplots(1,2, figsize=(10, 3))
    axs = axs.ravel();
    axs[0].axis('off')
    axs[0].imshow(copy_image)
    
    for i in range(5):
        print('%s: %.2f%%' % (top_k_pred[i].replace('\n', ''), top_k_val[i] * 100))

# %%
i = 0
display_pred_certainty(copy_images[i],my_images[i], top_k_vals[i], top_k_idxs[i])
# Out:
# Top 5 predictions for the following image (prediction: probability)
# Turn left ahead: 100.00%
# No entry: 0.00%
# Right-of-way at the next intersection: 0.00%
# No passing: 0.00%
# Slippery road: 0.00%

# %%
i = 1
display_pred_certainty(copy_images[i],my_images[i], top_k_vals[i], top_k_idxs[i])
# Out:
# Top 5 predictions for the following image (prediction: probability)
# Speed limit (70km/h): 100.00%
# Speed limit (30km/h): 0.00%
# Traffic signals: 0.00%
# Go straight or left: 0.00%
# Speed limit (50km/h): 0.00%

# %%
i = 2
display_pred_certainty(copy_images[i],my_images[i], top_k_vals[i], top_k_idxs[i])
# Out:
# Top 5 predictions for the following image (prediction: probability)
# Right-of-way at the next intersection: 100.00%
# Road narrows on the right: 0.00%
# Speed limit (20km/h): 0.00%
# Speed limit (30km/h): 0.00%
# Speed limit (50km/h): 0.00%

# %%
i = 3
display_pred_certainty(copy_images[i],my_images[i], top_k_vals[i], top_k_idxs[i])
# Out:
# Top 5 predictions for the following image (prediction: probability)
# General caution: 100.00%
# Traffic signals: 0.00%
# Right-of-way at the next intersection: 0.00%
# Pedestrians: 0.00%
# Speed limit (20km/h): 0.00%

# %%
i = 4
display_pred_certainty(copy_images[i],my_images[i], top_k_vals[i], top_k_idxs[i])
# Out:
# Top 5 predictions for the following image (prediction: probability)
# Keep right: 100.00%
# Speed limit (20km/h): 0.00%
# Speed limit (30km/h): 0.00%
# Speed limit (50km/h): 0.00%
# Speed limit (60km/h): 0.00%

# %%
i = 5
display_pred_certainty(copy_images[i],my_images[i], top_k_vals[i], top_k_idxs[i])
# Out:
# Top 5 predictions for the following image (prediction: probability)
# Speed limit (30km/h): 100.00%
# Speed limit (50km/h): 0.00%
# Yield: 0.00%
# End of all speed and passing limits: 0.00%
# Keep right: 0.00%
