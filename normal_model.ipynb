# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import tensorflow as tf
from tensorflow.contrib.layers import flatten
import pickle
import numpy as np
import matplotlib.pyplot as plt
import random
# %matplotlib inline
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
import cv2
import glob


from ml_library.config import *
from ml_library.utils import *
from ml_library.model import *
# Out:
# WARNING:tensorflow:Deprecation warnings have been disabled. Set TF_ENABLE_DEPRECATION_WARNINGS=1 to re-enable them.
# 1.15.5
# WARNING:tensorflow:From /utils.py:32: The name tf.train.GradientDescentOptimizer is deprecated. Please use tf.compat.v1.train.GradientDescentOptimizer instead.

# %%
# Load data
training_file = "./Datasets/GTSRB_Final_Training_Images.zip"
testing_file = "./Datasets/GTSRB_Final_Test_Images.zip"

train = generateTensor(training_file)
test = generateTensor(testing_file)
train_aug = data_aug(train)
test_aug = data_aug(test)

# x_train, y_train = split(train)
x_test, y_test = split(test)

label_map = map_labels('signnames.csv')

#Train/validation split
x_train, x_valid, y_train, y_valid = train_test_split(
    np.asarray(train['features']), np.asarray(train['labels']), test_size=VALIDATION_SIZE)


print("x_train shape:", x_train.shape)
print("y_train shape:", y_train.shape)
print("x_valid shape:", x_valid.shape)
print("y_valid shape:", y_valid.shape)
print("x_test shape:", x_test.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (39209, 32, 32, 3)
# y_train shape: (39209,)
# X_test shape: (12630, 32, 32, 3)
# y_test shape: (12630,)

# %%
#Visualization the dataset
import random
# %matplotlib inline

# show image of 10 random data points
fig, axs = plt.subplots(2,5, figsize=(15, 6))
fig.subplots_adjust(hspace = .2, wspace=.001)
axs = axs.ravel()
for i in range(10):
    index = random.randint(0, len(x_train))
    image = x_train[index]
    axs[i].axis('off')
    axs[i].imshow(image)
    axs[i].set_title(y_train[index])

# %%
BATCH_SIZE = 100  # batch size for training (relatively small)
BATCH_SIZE_INF = 2048  # batch size for running inference, e.g. calculating accuracy
VALIDATION_SIZE = 0.2  # fraction of total training set to use as validation set

# %%
## Normalize the train and test datasets to (-1,1)
x_train, y_train = preprocess_data(x_train, y_train)
x_test, y_test = preprocess_data(x_test, y_test)

x_train, X_valid, y_train, y_valid = train_test_split(x_train, y_train, test_size=VALIDATION_SIZE)

# %%
from tensorflow.contrib.layers import flatten

def LeNet2(x):    
    mu = 0
    sigma = 0.1
    
    # Layer 1: Convolutional. Input = 32x32x1. Output = 28x28x6.
    W1 = tf.Variable(tf.truncated_normal(shape=(5, 5, 1, 6), mean = mu, stddev = sigma), name="W1")
    x = tf.nn.conv2d(x, W1, strides=[1, 1, 1, 1], padding='VALID')
    b1 = tf.Variable(tf.zeros(6), name="b1")
    x = tf.nn.bias_add(x, b1)
    print("layer 1 shape:",x.get_shape())

    #Activation.
    x = tf.nn.relu(x)
    
    #Pooling. Input = 28x28x6. Output = 14x14x6.
    x = tf.nn.max_pool(x, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='VALID')
    layer1 = x
    
    #Layer 2: Convolutional. Output = 10x10x16.
    W2 = tf.Variable(tf.truncated_normal(shape=(5, 5, 6, 16), mean = mu, stddev = sigma), name="W2")
    x = tf.nn.conv2d(x, W2, strides=[1, 1, 1, 1], padding='VALID')
    b2 = tf.Variable(tf.zeros(16), name="b2")
    x = tf.nn.bias_add(x, b2)
                     
    #Activation.
    x = tf.nn.relu(x)

    #Pooling. Input = 10x10x16. Output = 5x5x16.
    x = tf.nn.max_pool(x, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='VALID')
    layer2 = x
    
    #Layer 3: Convolutional. Output = 1x1x400.
    W3 = tf.Variable(tf.truncated_normal(shape=(5, 5, 16, 400), mean = mu, stddev = sigma), name="W3")
    x = tf.nn.conv2d(x, W3, strides=[1, 1, 1, 1], padding='VALID')
    b3 = tf.Variable(tf.zeros(400), name="b3")
    x = tf.nn.bias_add(x, b3)
                     
    #Activation.
    x = tf.nn.relu(x)
    layer3 = x

    #Flatten. Input = 5x5x16. Output = 400.
    layer2flat = flatten(layer2)
    print("layer2flat shape:",layer2flat.get_shape())
    
    # Flatten x. Input = 1x1x400. Output = 400.
    xflat = flatten(x)
    print("xflat shape:",xflat.get_shape())
    
    # Concat layer2flat and x. Input = 400 + 400. Output = 800
    x = tf.concat([xflat, layer2flat], 1)
    print("x shape:",x.get_shape())
    
    # Dropout
    x = tf.nn.dropout(x, keep_prob)
    
    #Layer 4: Fully Connected. Input = 800. Output = 43.
    W4 = tf.Variable(tf.truncated_normal(shape=(800, 43), mean = mu, stddev = sigma), name="W4")
    b4 = tf.Variable(tf.zeros(43), name="b4")    
    logits = tf.add(tf.matmul(x, W4), b4)
    

    
    return logits

print('done')
# Out:
# done

# %%
tf.reset_default_graph() 

x = tf.placeholder(tf.float32, (None, IMG_SIZE, IMG_SIZE, 3))
y = tf.placeholder(tf.float32, (None, NUM_CLASSES))
keep_prob = tf.placeholder(tf.float32) # probability to keep units
print('done')
# Out:
# done

# %%
rate = 0.0009

logits = LeNet2(x)
cross_entropy = tf.nn.softmax_cross_entropy_with_logits(labels = y, logits = logits)
loss_operation = tf.reduce_mean(cross_entropy)
optimizer = tf.train.AdamOptimizer(learning_rate = rate)
training_operation = optimizer.minimize(loss_operation)
correct_prediction = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy_operation = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
saver = tf.train.Saver()
# Out:
# layer 1 shape: (?, 28, 28, 6)
# layer2flat shape: (?, 400)
# xflat shape: (?, 400)
# x shape: (?, 800)

# %%
def evaluate(X_data, y_data):
    num_examples = len(X_data)
    total_accuracy = 0
    sess = tf.get_default_session()
    for offset in range(0, num_examples, BATCH_SIZE):
        batch_x, batch_y = X_data[offset:offset+BATCH_SIZE], y_data[offset:offset+BATCH_SIZE]
        accuracy = sess.run(accuracy_operation, feed_dict={x: batch_x, y: batch_y, keep_prob: 1.0})
        total_accuracy += (accuracy * len(batch_x))
    return total_accuracy / num_examples

print('done')
# Out:
# done

# %%
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    num_examples = len(x_train)
    
    print("Let's start the training...")
    print()
    for i in range(NUM_EPOCH):
        for offset in range(0, num_examples, BATCH_SIZE):
            end = offset + BATCH_SIZE
            batch_x, batch_y = x_train[offset:end], y_train[offset:end]
            sess.run(training_operation, feed_dict={x: batch_x, y: batch_y, keep_prob: 0.5})
            
        validation_accuracy = evaluate(X_valid, y_valid)
        print("EPOCH {} ...".format(i+1))
        print("Validation Accuracy = {:.3f}".format(validation_accuracy))
        print()
        
    saver.save(sess, './models/normal_model')
    print("Model saved")
# Out:
# Let's start the training...
#
# EPOCH 1 ...
# Validation Accuracy = 0.054
#
# EPOCH 2 ...
# Validation Accuracy = 0.076
#
# EPOCH 3 ...
# Validation Accuracy = 0.110
#
# EPOCH 4 ...
# Validation Accuracy = 0.231
#
# EPOCH 5 ...
# Validation Accuracy = 0.480
#
# EPOCH 6 ...
# Validation Accuracy = 0.710
#
# EPOCH 7 ...
# Validation Accuracy = 0.801
#
# EPOCH 8 ...
# Validation Accuracy = 0.848
#
# EPOCH 9 ...
# Validation Accuracy = 0.884
#
# EPOCH 10 ...
# Validation Accuracy = 0.901
#
# EPOCH 11 ...
# Validation Accuracy = 0.905
#
# EPOCH 12 ...
# Validation Accuracy = 0.920
#
# EPOCH 13 ...
# Validation Accuracy = 0.925
#
# EPOCH 14 ...
# Validation Accuracy = 0.933
#
# EPOCH 15 ...
# Validation Accuracy = 0.939
#
# EPOCH 16 ...
# Validation Accuracy = 0.938
#
# EPOCH 17 ...
# Validation Accuracy = 0.948
#
# EPOCH 18 ...
# Validation Accuracy = 0.952
#
# EPOCH 19 ...
# Validation Accuracy = 0.952
#
# EPOCH 20 ...
# Validation Accuracy = 0.958
#
# EPOCH 21 ...
# Validation Accuracy = 0.962
#
# EPOCH 22 ...
# Validation Accuracy = 0.959
#
# EPOCH 23 ...
# Validation Accuracy = 0.961
#
# EPOCH 24 ...
# Validation Accuracy = 0.963
#
# EPOCH 25 ...
# Validation Accuracy = 0.965
#
# EPOCH 26 ...
# Validation Accuracy = 0.969
#
# EPOCH 27 ...
# Validation Accuracy = 0.957
#
# EPOCH 28 ...
# Validation Accuracy = 0.967
#
# EPOCH 29 ...
# Validation Accuracy = 0.958
#
# EPOCH 30 ...
# Validation Accuracy = 0.974
#
# EPOCH 31 ...
# Validation Accuracy = 0.957
#
# EPOCH 32 ...
# Validation Accuracy = 0.970
#
# EPOCH 33 ...
# Validation Accuracy = 0.974
#
# EPOCH 34 ...
# Validation Accuracy = 0.973
#
# EPOCH 35 ...
# Validation Accuracy = 0.972
#
# EPOCH 36 ...
# Validation Accuracy = 0.971
#
# EPOCH 37 ...
# Validation Accuracy = 0.971
#
# EPOCH 38 ...
# Validation Accuracy = 0.975
#
# EPOCH 39 ...
# Validation Accuracy = 0.961
#
# EPOCH 40 ...
# Validation Accuracy = 0.973
#
# EPOCH 41 ...
# Validation Accuracy = 0.974
#
# EPOCH 42 ...
# Validation Accuracy = 0.977
#
# EPOCH 43 ...
# Validation Accuracy = 0.976
#
# EPOCH 44 ...
# Validation Accuracy = 0.976
#
# EPOCH 45 ...
# Validation Accuracy = 0.971
#
# EPOCH 46 ...
# Validation Accuracy = 0.974
#
# EPOCH 47 ...
# Validation Accuracy = 0.955
#
# EPOCH 48 ...
# Validation Accuracy = 0.977
#
# EPOCH 49 ...
# Validation Accuracy = 0.975
#
# EPOCH 50 ...
# Validation Accuracy = 0.978
#
# EPOCH 51 ...
# Validation Accuracy = 0.976
#
# EPOCH 52 ...
# Validation Accuracy = 0.978
#
# EPOCH 53 ...
# Validation Accuracy = 0.979
#
# EPOCH 54 ...
# Validation Accuracy = 0.979
#
# EPOCH 55 ...
# Validation Accuracy = 0.981
#
# EPOCH 56 ...
# Validation Accuracy = 0.978
#
# EPOCH 57 ...
# Validation Accuracy = 0.978
#
# EPOCH 58 ...
# Validation Accuracy = 0.978
#
# EPOCH 59 ...
# Validation Accuracy = 0.980
#
# EPOCH 60 ...
# Validation Accuracy = 0.979
#
# Model saved

# %%
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    saver2 = tf.train.import_meta_graph('./models/normal_model.meta')
    saver2.restore(sess, "./models/normal_model")
    test_accuracy = evaluate(x_test, y_test)
    print("Test Set Accuracy = {:.3f}".format(test_accuracy))
# Out:
# INFO:tensorflow:Restoring parameters from ./normal_model
# Test Set Accuracy = 0.913

# %%
import copy
def rain(images, eps):
    x = copy.copy(images)
    batch_size = images.shape[0]
    for i in range(batch_size):
#         if np.mean(x[i]) > 100 and i < 1:
#             x[i] = x[i] / (1+eps*0.15)
        for j in range(eps*40):
            np.random.seed(j)
            x_idx = np.random.randint(0, 32)
            y_idx = np.random.randint(0, 32)
            x[i, x_idx:x_idx+2, y_idx, :] = 0.8*x[i, x_idx:x_idx+2, y_idx, :] + 0.2*255
    x = np.clip(x, 0., 255.)
    return x

# %%
def fog(images, eps):
    x = copy.copy(images)
    batch_size = images.shape[0]
#     x = x / (eps*0.3+1) + eps * 10
    x = x *(1-eps*0.04) + eps * 7
#     for i in range(batch_size):
#         image = x[i].reshape(32, 32, 3)
#         temp = gaussian_filter(image, sigma=0.7)
#         x[i] = temp
    x = np.clip(x, 0., 255.)
    return x

# %%
import copy
def dark(images, eps):
    x = copy.copy(images)
    x = x - eps*10.
    x = np.clip(x, 0., 255.)
    return x

def light(images, eps):
    x = copy.copy(images)
    x = x + eps*10.
    x = np.clip(x, 0., 255.)
    return x

# %%
from scipy.ndimage.filters import gaussian_filter

def blur(images, eps):
    batch_size = images.shape[0]
    x = np.zeros(images.shape)
    for i in range(batch_size):
        image = images[i].reshape(32, 32, 3)
        temp = gaussian_filter(image, sigma=0.5+eps*0.1)
        x[i] = temp
    return x

# %%
def ocul(images, eps):
    batch_size = images.shape[0]
    x = copy.copy(images)
    for i in range(batch_size):
        image = images[i].reshape(32, 32, 3)
        idx = np.random.randint(0, 32-eps)
        x[i, idx:idx+eps, idx:idx+eps, :] = 0.
#         x[i] = image
    return x

# %%
# Out:
# X_test shape: (12630, 32, 32, 3)
# y_test shape: (12630,)

# %%
testing_file = './Datasets/GTSRB_Final_Test_Images.zip'
test = generateTensor(testing_file)
X_test, y_test = preprocess_data(test)
print("x_test shape:", x_test.shape)
print("y_test shape:", y_test.shape)

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    saver3 = tf.train.import_meta_graph('./models/normal_model.meta')
    saver3.restore(sess, "./models/normal_model")
    acc = evaluate(x_test, y_test)
    print("Test Set Accuracy = {:.3f}".format(acc))
    for i in range(20):
        rain_images = rain(x_test, i)
        adv_acc = evaluate(rain_images, y_test)
        print("Rain Drops %.2d  vs. Accuracy vs Adv_Accuracy：" % i, acc, adv_acc)
    for i in range(20):
        rain_images = fog(x_test, i)
        adv_acc = evaluate(rain_images, y_test)
        print("fog Drops %.2d  vs. Accuracy vs Adv_Accuracy：" % i, acc, adv_acc)
    for i in range(20):
        rain_images = light(x_test, i)
        adv_acc = evaluate(rain_images, y_test)
        print("light Drops %.2d  vs. Accuracy vs Adv_Accuracy：" % i, acc, adv_acc)
    for i in range(20):
        rain_images = dark(x_test, i)
        adv_acc = evaluate(rain_images, y_test)
        print("dark Drops %.2d  vs. Accuracy vs Adv_Accuracy：" % i, acc, adv_acc)
    for i in range(20):
        rain_images = blur(x_test, i)
        adv_acc = evaluate(rain_images, y_test)
        print("Blur deviation %.2d  vs. Accuracy vs Adv_Accuracy：" % i, acc, adv_acc)
# Out:
# INFO:tensorflow:Restoring parameters from ./normal_model
# Test Set Accuracy = 0.913
# Rain Drops 00  vs. Accuracy vs Adv_Accuracy： 0.9133808431130784 0.9133808431130784
# Rain Drops 01  vs. Accuracy vs Adv_Accuracy： 0.9133808431130784 0.7733966753960411
# Rain Drops 02  vs. Accuracy vs Adv_Accuracy： 0.9133808431130784 0.7177355532030784
# Rain Drops 03  vs. Accuracy vs Adv_Accuracy： 0.9133808431130784 0.6944576427281517
# Rain Drops 04  vs. Accuracy vs Adv_Accuracy： 0.9133808431130784 0.6665083159554693
# Rain Drops 05  vs. Accuracy vs Adv_Accuracy： 0.9133808431130784 0.6505938265782354
# Rain Drops 06  vs. Accuracy vs Adv_Accuracy： 0.9133808431130784 0.6384798112787713
# Rain Drops 07  vs. Accuracy vs Adv_Accuracy： 0.9133808431130784 0.6111638940522715
# Rain Drops 08  vs. Accuracy vs Adv_Accuracy： 0.9133808431130784 0.5952494027873211
# Rain Drops 09  vs. Accuracy vs Adv_Accuracy： 0.9133808431130784 0.5829770360215731
# Rain Drops 10  vs. Accuracy vs Adv_Accuracy： 0.9133808431130784 0.5310372085393844
# Rain Drops 11  vs. Accuracy vs Adv_Accuracy： 0.9133808431130784 0.51266824887654
# Rain Drops 12  vs. Accuracy vs Adv_Accuracy： 0.9133808431130784 0.5055423562996745
# Rain Drops 13  vs. Accuracy vs Adv_Accuracy： 0.9133808431130784 0.46935866616212085
# Rain Drops 14  vs. Accuracy vs Adv_Accuracy： 0.9133808431130784 0.4731591437557625
# Rain Drops 15  vs. Accuracy vs Adv_Accuracy： 0.9133808431130784 0.5091844790999321
# Rain Drops 16  vs. Accuracy vs Adv_Accuracy： 0.9133808431130784 0.5163895454278373
# Rain Drops 17  vs. Accuracy vs Adv_Accuracy： 0.9133808431130784 0.4823436218174506
# Rain Drops 18  vs. Accuracy vs Adv_Accuracy： 0.9133808431130784 0.46405383755739776
# Rain Drops 19  vs. Accuracy vs Adv_Accuracy： 0.9133808431130784 0.4516231172016851
# Blur deviation 03  vs. Accuracy vs Adv_Accuracy： 0.9133808431130784 0.899445765139277
# Blur deviation 04  vs. Accuracy vs Adv_Accuracy： 0.9133808431130784 0.8882818694446923
# Blur deviation 05  vs. Accuracy vs Adv_Accuracy： 0.9133808431130784 0.8748218522879782
# Blur deviation 06  vs. Accuracy vs Adv_Accuracy： 0.9133808431130784 0.8589865389270435
# Blur deviation 07  vs. Accuracy vs Adv_Accuracy： 0.9133808431130784 0.8397466324665012
# Blur deviation 08  vs. Accuracy vs Adv_Accuracy： 0.9133808431130784 0.817260488572804
# Blur deviation 09  vs. Accuracy vs Adv_Accuracy： 0.9133808431130784 0.791844814142724
# Blur deviation 10  vs. Accuracy vs Adv_Accuracy： 0.9133808431130784 0.7578780676576701
# Blur deviation 11  vs. Accuracy vs Adv_Accuracy： 0.9133808431130784 0.7191607295192619
# Blur deviation 12  vs. Accuracy vs Adv_Accuracy： 0.9133808431130784 0.6761678542679298
# Blur deviation 13  vs. Accuracy vs Adv_Accuracy： 0.9133808431130784 0.6357086294714837
# Blur deviation 14  vs. Accuracy vs Adv_Accuracy： 0.9133808431130784 0.5905779906897345
# Blur deviation 15  vs. Accuracy vs Adv_Accuracy： 0.9133808431130784 0.5438638130823771
# Blur deviation 16  vs. Accuracy vs Adv_Accuracy： 0.9133808431130784 0.4926365754100319
# Blur deviation 17  vs. Accuracy vs Adv_Accuracy： 0.9133808431130784 0.4448931093548181
# Blur deviation 18  vs. Accuracy vs Adv_Accuracy： 0.9133808431130784 0.39509105203365014
# Blur deviation 19  vs. Accuracy vs Adv_Accuracy： 0.9133808431130784 0.35368171103021406

# %%
#reading in an image
import glob
import matplotlib.image as mpimg

fig, axs = plt.subplots(2,4, figsize=(4, 2))
fig.subplots_adjust(hspace = .2, wspace=.001)
axs = axs.ravel()

my_images = []

for i, img in enumerate(glob.glob('./traffic-signs-test/*x.png')):
    image = cv2.imread(img)
    axs[i].axis('off')
    axs[i].imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    image = np.reshape(image, (32, 32, 3))
    my_images.append(image)

my_images = np.asarray(my_images,dtype='uint8')
copy_images = my_images

# %%
label_map = {}
with open('signnames.csv', 'r') as f:
    first_line = True
    for line in f:
        # Ignore first line
        if first_line:
            first_line = False
            continue

        # Populate label_map
        label_int, label_string = line.split(',')
        label_int = int(label_int)

        label_map[label_int] = label_string

# %%
print(label_map)
# Out:
# {0: 'Speed limit (20km/h)\n', 1: 'Speed limit (30km/h)\n', 2: 'Speed limit (50km/h)\n', 3: 'Speed limit (60km/h)\n', 4: 'Speed limit (70km/h)\n', 5: 'Speed limit (80km/h)\n', 6: 'End of speed limit (80km/h)\n', 7: 'Speed limit (100km/h)\n', 8: 'Speed limit (120km/h)\n', 9: 'No passing\n', 10: 'No passing for vechiles over 3.5 metric tons\n', 11: 'Right-of-way at the next intersection\n', 12: 'Priority road\n', 13: 'Yield\n', 14: 'Stop\n', 15: 'No vechiles\n', 16: 'Vechiles over 3.5 metric tons prohibited\n', 17: 'No entry\n', 18: 'General caution\n', 19: 'Dangerous curve to the left\n', 20: 'Dangerous curve to the right\n', 21: 'Double curve\n', 22: 'Bumpy road\n', 23: 'Slippery road\n', 24: 'Road narrows on the right\n', 25: 'Road work\n', 26: 'Traffic signals\n', 27: 'Pedestrians\n', 28: 'Children crossing\n', 29: 'Bicycles crossing\n', 30: 'Beware of ice/snow\n', 31: 'Wild animals crossing\n', 32: 'End of all speed and passing limits\n', 33: 'Turn right ahead\n', 34: 'Turn left ahead\n', 35: 'Ahead only\n', 36: 'Go straight or right\n', 37: 'Go straight or left\n', 38: 'Keep right\n', 39: 'Keep left\n', 40: 'Roundabout mandatory\n', 41: 'End of no passing\n', 42: 'End of no passing by vechiles over 3.5 metric tons\n'}

# %%
my_images, _ = preprocess_data(my_images, np.array([0 for _ in range(my_images.shape[0])]))

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    saver3 = tf.train.import_meta_graph('./models/normal_model.meta')
    saver3.restore(sess, "./models/normal_model")
    lgts, preds = sess.run([logits, predictions], feed_dict={x: my_images, keep_prob: 1.})
    final_preds = [label_map[pred] for pred in preds]
# Out:
# INFO:tensorflow:Restoring parameters from ./normal_model
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-1044efb48270> in <module>
#       5     saver3 = tf.train.import_meta_graph('./normal_model.meta')
#       6     saver3.restore(sess, "./normal_model")
# ----> 7     lgts, preds = sess.run([logits, predictions], feed_dict={x: my_images, keep_prob: 1.})
#       8     final_preds = [label_map[pred] for pred in preds]
#
# NameError: name 'predictions' is not defined

# %%
# Print predictions on my sample images
print('Predictions on sample images\n')
for i in range(my_images.shape[0]):
    print('%s' % (final_preds[i]))

# %%
with tf.Graph().as_default(), tf.Session() as sess:
    logits = tf.placeholder('float', [None, NUM_CLASSES])
    softmax = tf.nn.softmax(logits)
    top_k_val, top_k_idx = tf.nn.top_k(softmax, k=5)
    
    top_k_vals, top_k_idxs = sess.run([top_k_val, top_k_idx], feed_dict={logits: lgts})

# %%
def display_pred_certainty(copy_image, image, top_k_val, top_k_idx):
    print('Top 5 predictions for the following image (prediction: probability)')
    # Convert top k indices into strings
    top_k_pred = [label_map[idx] for idx in top_k_idx]
    
    # Show the image for reference
    fig, axs = plt.subplots(1,2, figsize=(10, 3))
    axs = axs.ravel();
    axs[0].axis('off')
    axs[0].imshow(copy_image)
    
    for i in range(5):
        print('%s: %.2f%%' % (top_k_pred[i].replace('\n', ''), top_k_val[i] * 100))

# %%
i = 0
display_pred_certainty(copy_images[i],my_images[i], top_k_vals[i], top_k_idxs[i])

# %%
i = 1
display_pred_certainty(copy_images[i],my_images[i], top_k_vals[i], top_k_idxs[i])

# %%
i = 2
display_pred_certainty(copy_images[i],my_images[i], top_k_vals[i], top_k_idxs[i])

# %%
i = 3
display_pred_certainty(copy_images[i],my_images[i], top_k_vals[i], top_k_idxs[i])

# %%
i = 4
display_pred_certainty(copy_images[i],my_images[i], top_k_vals[i], top_k_idxs[i])

# %%
i = 5
display_pred_certainty(copy_images[i],my_images[i], top_k_vals[i], top_k_idxs[i])
